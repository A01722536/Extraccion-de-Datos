# %% [markdown]
# **Variable: Los registros de 5 “host name” diferentes**

# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mallorca=pd.read_excel("Actividad2.0.Mallorca.xlsx")

# %%
nombre=mallorca[(mallorca["host_name"] == "Natalia")|(mallorca["host_name"]== "Guillermo")|(mallorca["host_name"]== "Vivian")|(mallorca["host_name"]== "Peter")|(mallorca["host_name"]== "Marc")]
nombre
# Out:
#                         id                                       listing_url  \
# 8                   233901               https://www.airbnb.com/rooms/233901
# 9                   238799               https://www.airbnb.com/rooms/238799
# 12                  268350               https://www.airbnb.com/rooms/268350
# 15                  639787               https://www.airbnb.com/rooms/639787
# 43                  744388               https://www.airbnb.com/rooms/744388
# ...                    ...                                               ...
# 15344  1197093936955353590  https://www.airbnb.com/rooms/1197093936955353590
# 15484  1209881252383551228  https://www.airbnb.com/rooms/1209881252383551228
# 15534  1226200906357904815  https://www.airbnb.com/rooms/1226200906357904815
# 15605  1228888859796105705  https://www.airbnb.com/rooms/1228888859796105705
# 16027  1255918018386617190  https://www.airbnb.com/rooms/1255918018386617190
#
# ...
