# %% [markdown]
# **Variable: Los registros de los host cuyo “host_response_rate” sea mayor a 95% y que no sean “superhost”**

# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mallorca=pd.read_excel("Actividad2.0.Mallorca.xlsx")

# %%
super_respuesta=mallorca[(mallorca["host_response_rate"] > 0.95)&(mallorca["host_is_superhost"] == "f")]
super_respuesta
# Out:
#                         id                                       listing_url  \
# 4                   166820               https://www.airbnb.com/rooms/166820
# 5                   168668               https://www.airbnb.com/rooms/168668
# 8                   233901               https://www.airbnb.com/rooms/233901
# 11                  257206               https://www.airbnb.com/rooms/257206
# 16                  641406               https://www.airbnb.com/rooms/641406
# ...                    ...                                               ...
# 16862  1308224357787269852  https://www.airbnb.com/rooms/1308224357787269852
# 16863  1308461808126489151  https://www.airbnb.com/rooms/1308461808126489151
# 16864  1308461814550170824  https://www.airbnb.com/rooms/1308461814550170824
# 16865  1308461822310864061  https://www.airbnb.com/rooms/1308461822310864061
# 16866  1308461864517468049  https://www.airbnb.com/rooms/1308461864517468049
#
# ...
