# %% [markdown]
# **Variable: Los registros de los tipos de cuarto: “Hotel room” o “Private room”**

# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mallorca=pd.read_excel("Actividad2.0.Mallorca.xlsx")

# %%
cuarto=mallorca[(mallorca["room_type"] == "Hotel room")|(mallorca["room_type"]== "Private room")]
cuarto
# Out:
#                         id                                       listing_url  \
# 3                   164185               https://www.airbnb.com/rooms/164185
# 4                   166820               https://www.airbnb.com/rooms/166820
# 7                   210156               https://www.airbnb.com/rooms/210156
# 11                  257206               https://www.airbnb.com/rooms/257206
# 13                  323164               https://www.airbnb.com/rooms/323164
# ...                    ...                                               ...
# 16855  1307967085314406590  https://www.airbnb.com/rooms/1307967085314406590
# 16862  1308224357787269852  https://www.airbnb.com/rooms/1308224357787269852
# 16863  1308461808126489151  https://www.airbnb.com/rooms/1308461808126489151
# 16864  1308461814550170824  https://www.airbnb.com/rooms/1308461814550170824
# 16865  1308461822310864061  https://www.airbnb.com/rooms/1308461822310864061
#
# ...
